# %% [markdown]
# ### Cloning repository on google colab

# %%
! git clone https://github.com/clovaai/deep-text-recognition-benchmark
# Out:
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 499, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 499 (delta 208), reused 200 (delta 200), pack-reused 274 (from 1)
# Receiving objects: 100% (499/499), 3.05 MiB | 7.12 MiB/s, done.
# Resolving deltas: 100% (308/308), done.

# %%
# %cd deep-text-recognition-benchmark
# Out:
# /content/deep-text-recognition-benchmark

# %% [markdown]
# ### Choosing a pre-trained model and downloading it

# %%
# !gdown 1b59rXuGGmKne1AuHnkgDzoYgKeETNMv9
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1b59rXuGGmKne1AuHnkgDzoYgKeETNMv9
# From (redirected): https://drive.google.com/uc?id=1b59rXuGGmKne1AuHnkgDzoYgKeETNMv9&confirm=t&uuid=a94a1735-c113-4b99-97c6-5c102cf92376
# To: /content/deep-text-recognition-benchmark/TPS-ResNet-BiLSTM-Attn.pth
# 100% 199M/199M [00:04<00:00, 49.0MB/s]

# %%
# !pip install lmdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 7.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Running demo

# %%
# !python3 demo.py \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
--image_folder demo_image/ \
--saved_model TPS-ResNet-BiLSTM-Attn.pth
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/demo_1.png    	available                	0.9999
# demo_image/demo_2.jpg    	shakeshack               	0.9530
# ...

# %% [markdown]
# ### Running Inference on English and Persian hand-writing text images

# %%
# !python3 demo.py \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
--image_folder input_English/ \
--saved_model TPS-ResNet-BiLSTM-Attn.pth
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# ...

# %%
# !python3 demo.py \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
--image_folder input_Persian/ \
--saved_model TPS-ResNet-BiLSTM-Attn.pth
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# ...

# %% [markdown]
# ### Running Inference on English and Persian license plate images

# %%
# !python3 demo.py \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
--image_folder input_license_plates/ \
--saved_model TPS-ResNet-BiLSTM-Attn.pth
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# input_license_plates/lp_En2.jpg	cdvd24201                	0.2216
# input_license_plates/lp_En.jpg	hulb619                  	0.2116
# ...
